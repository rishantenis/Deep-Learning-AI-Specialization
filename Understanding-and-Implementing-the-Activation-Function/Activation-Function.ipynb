# %% [markdown]
# <html>
# <body>
#
#
# <p style="font-family: Goole Sans", Roboto, Arial, sans-serif;><center>
# Understanding-and-Implementing-the-Activation-Function </center>
# </p>
#
# </body>
# </html>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-5, 5, 0.01)

# %%
def plot(func, yaxis=(-1.4, 1.4)):
    plt.ylim(yaxis)
    plt.locator_params(nbins=5)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.axhline(lw=1, c='black')
    plt.axvline(lw=1, c='black')
    plt.grid(alpha=0.4, ls='-.')
    plt.box(on=None)
    plt.plot(x, func(x), c='r', lw=3)

# %% [markdown]
# ## Binary Step

# %% [markdown]
# $$
# f(x) = \left\{
#         \begin{array}{lll}
#             0 & for & x \leq 0  \\
#             1 & for & x > 0
#         \end{array}
#     \right.
# $$

# %% [markdown]
# $$
# f'(x) = \left\{
#         \begin{array}{lll}
#             0 & for & x \neq 0  \\
#             ? & for & x = 0
#         \end{array}
#     \right.
# $$

# %%
binary_step = np.vectorize(lambda x: 1 if x > 0 else 0, otypes=[np.float])
# Out:
# c:\Users\Tenis\anaconda3\envs\Data_Sci\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# $$
# f(x) = \left\{
#         \begin{array}{lll}
#             0 & for & x < x_{min} \\
#             mx+b & for & x_{min} \leq x \leq x_{max}  \\
#             1 & for & x > x_{max}
#         \end{array}
#     \right.
# $$

# %% [markdown]
# $$
# f'(x) = \left\{
#         \begin{array}{lll}
#             0 & for & x < x_{min} \\
#             m & for & x_{min} \leq x \leq x_{max}  \\
#             0 & for & x > x_{max}
#         \end{array}
#     \right.
# $$

# %%
piecewise_linear = np.vectorize(lambda x: 1 if x > 3 else 0 if x < -3 else 1/6*x+1/2, otypes=[np.float])
# Out:
# c:\Users\Tenis\anaconda3\envs\Data_Sci\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
plot(piecewise_linear, yaxis=(-0.4, 1.4))

# %% [markdown]
# ## Bipolar

# %% [markdown]
# $$
# f(x) = \left\{
#         \begin{array}{lll}
#             -1 & for & x \leq 0  \\
#             1 & for & x > 0
#         \end{array}
#     \right.
# $$

# %% [markdown]
# $$
# f'(x) = \left\{
#         \begin{array}{lll}
#             0 & for & x \neq 0  \\
#             ? & for & x = 0
#         \end{array}
#     \right.
# $$

# %%
bipolar = np.vectorize(lambda x: 1 if x > 0 else -1, otypes=[np.float])
# Out:
# c:\Users\Tenis\anaconda3\envs\Data_Sci\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
plot(bipolar)

# %% [markdown]
# ## Sigmoid

# %% [markdown]
# $$
# f(x)={\frac {1}{1+e^{-x}}}
# $$

# %% [markdown]
# $$
# f'(x)=f(x)(1-f(x))
# $$

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
plot(sigmoid, yaxis=(-0.4, 1.4))

# %% [markdown]
# ## Bipolar Sigmoid

# %% [markdown]
# $$
# f(x)={\frac {1-e^{-x}}{1+e^{-x}}}
# $$

# %% [markdown]
# $$
# f'(x)={\frac {2e^x}{(e^x+1)^2}}
# $$

# %%
def bipolar_sigmoid(x):
    return (1 - np.exp(-x)) / (1 + np.exp(-x))

# %%
plot(bipolar_sigmoid)

# %% [markdown]
# ## Hyperbolic Tangent, TanH

# %% [markdown]
# $$
# f(x)={\frac {2}{1+e^{-2x}}}-1
# $$

# %% [markdown]
# $$
# f'(x)=1-f(x)^2
# $$

# %%
def tanh(x):
    return 2 / (1 + np.exp(-2 * x)) -1

# %%
plot(tanh)

# %% [markdown]
# ## Arctangent, ArcTan

# %% [markdown]
# $$
# f(x)=tan^{-1}(x)
# $$

# %% [markdown]
# $$
# f'(x)={\frac {1}{1+x^2}}
# $$

# %%
def arctan(x):
    return np.arctan(x)

# %%
plot(arctan)

# %% [markdown]
# ## Rectified Linear Units, ReLU

# %% [markdown]
# $$
# f(x) = \left\{
#         \begin{array}{lll}
#             0 & for & x \leq 0  \\
#             x & for & x > 0
#         \end{array}
#     \right.
# $$

# %%
relu = np.vectorize(lambda x: x if x > 0 else 0, otypes=[np.float])
# Out:
# c:\Users\Tenis\anaconda3\envs\Data_Sci\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
plot(relu, yaxis=(-0.4, 1.4))

# %% [markdown]
# ## Leaky Rectified Linear Units, Leaky ReLU

# %% [markdown]
# $$
# f(x) = \left\{
#         \begin{array}{lll}
#             ax & for & x \leq 0  \\
#             x & for & x > 0
#         \end{array}
#     \right.
# $$

# %% [markdown]
# $$
# f'(x) = \left\{
#         \begin{array}{lll}
#             a & for & x \leq 0  \\
#             1 & for & x > 0
#         \end{array}
#     \right.
# $$

# %%
leaky_relu = np.vectorize(lambda x: max(0.1 * x, x), otypes=[np.float])
# Out:
# c:\Users\Tenis\anaconda3\envs\Data_Sci\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
plot(leaky_relu)

# %% [markdown]
# Parametric ReLU is similar to Leaky ReLU but coefficient of leakage is learned as parameter of neural network

# %% [markdown]
# ## Exponential Linear Units, ELU

# %% [markdown]
# $$
# f(x) = \left\{
#         \begin{array}{lll}
#             a(e^x-1) & for & x \leq 0  \\
#             x & for & x > 0
#         \end{array}
#     \right.
# $$

# %% [markdown]
# $$
# f'(x) = \left\{
#         \begin{array}{lll}
#             f(x)+a & for & x \leq 0  \\
#             1 & for & x > 0
#         \end{array}
#     \right.
# $$

# %%
elu = np.vectorize(lambda x: x if x > 0 else 0.5 * (np.exp(x) - 1), otypes=[np.float])
# Out:
# c:\Users\Tenis\anaconda3\envs\Data_Sci\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
plot(elu)

# %% [markdown]
# ## SoftPlus

# %% [markdown]
# $$
# f(x)=ln(1+e^x)
# $$

# %% [markdown]
# $$
# f'(x)={\frac {1}{1+e^{-x}}}
# $$

# %%
def softplus(x):
    return np.log(1+np.exp(x))

# %%
plot(softplus, yaxis=(-0.4, 1.4))
